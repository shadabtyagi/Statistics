# %% [markdown]
# # What is the difference between descriptive statistics and inferential?statistics? Explain with examples.
# >>Descriptive statistics describe "what is," while inferential statistics conclude "what next
# # What is sampling in statistics? Explain the differences between random and stratified sampling.
#
# >>the statistical process of selecting a subset of individuals or observations from a larger population to make inferences, reduce costs, and save time.
#
# # Define mean, median, and mode. Explain why these measures of central
# tendency are important.
#
# >>statistical measures that identify the center or typical value of a dataset
#
# # Explain skewness and kurtosis. What does a positive skew imply about the
# data?
#
# >>Positive skew indicates a right-skewed distribution where the mean is greater than the median, with a long tail on the right side indicating outliers or higher
#
# #  Implement a Python program to compute the mean, median, and mode of
# a given list of numbers.
#
# >>import statistics
#
# numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]
#
# # Compute mean, median, and mode
# mean_val = statistics.mean(numbers)
# median_val = statistics.median(numbers)
# mode_val = statistics.multimode(numbers)  # Handles multiple modes if they exist
#
# print(f"Mean: {mean_val}")
# print(f"Median: {median_val}")
# print(f"Mode(s): {mode_val}")
#
# #
